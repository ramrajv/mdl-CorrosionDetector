# %% [markdown]
# <a href="https://colab.research.google.com/github/ramrajv/mdl-CorrosionDetector/blob/master/Rust_Detection_Trained_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import load_model
from keras_preprocessing.image import load_img
from keras.layers.serialization import image_preprocessing
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
trnd_mod = '/content/drive/MyDrive/Docs/MDL/CorrosionDetector-master/download/rustnorust_b/rustnorust_model.h5'

# returns a compiled model
# identical to the previous one
model = load_model(trnd_mod)

# %%
img_path = '/content/WIN_20221019_13_32_24_Pro.jpg'

# Read the image and resize it
img = image_preprocessing.image_utils.load_img(img_path, target_size=(150, 150))

plt.imshow(img)
# Convert it to a Numpy array with shape (150, 150, 3)
test_x = image_preprocessing.image_utils.img_to_array(img)
# Reshape it to (1, 150, 150, 3)
test_x = test_x.reshape((1,) + test_x.shape)
test_x = test_x.astype('float32') / 255
rust_prob = model.predict(test_x)

if (rust_prob > 0.5):
    print("This is a Rust image")
else:
    print("This is a no Rust image")
# Out:
# 1/1 [==============================] - 0s 401ms/step
# This is a Rust image

# %%
img_path = '/content/WhatsApp Image 2022-10-14 at 13.00.19.jpg'

# Read the image and resize it
img = image_preprocessing.image_utils.load_img(img_path, target_size=(150, 150))

plt.imshow(img)
# Convert it to a Numpy array with shape (150, 150, 3)
test_x = image_preprocessing.image_utils.img_to_array(img)
# Reshape it to (1, 150, 150, 3)
test_x = test_x.reshape((1,) + test_x.shape)
test_x = test_x.astype('float32') / 255
rust_prob = model.predict(test_x)

if (rust_prob > 0.5):
    print("This is a Rust image")
else:
    print("This is a no Rust image")
# Out:
# 1/1 [==============================] - 0s 235ms/step
# This is a Rust image

# %%
img_path = '/content/AtStall51.jpg'

# Read the image and resize it
img = image_preprocessing.image_utils.load_img(img_path, target_size=(150, 150))

plt.imshow(img)
# Convert it to a Numpy array with shape (150, 150, 3)
test_x = image_preprocessing.image_utils.img_to_array(img)
# Reshape it to (1, 150, 150, 3)
test_x = test_x.reshape((1,) + test_x.shape)
test_x = test_x.astype('float32') / 255
rust_prob = model.predict(test_x)

if (rust_prob > 0.5):
    print("This is a Rust image")
else:
    print("This is a no Rust image")
# Out:
# 1/1 [==============================] - 1s 616ms/step
# This is a no Rust image
